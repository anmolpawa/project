# %% [markdown]
# # Anmol Pawa

# %% [markdown]
# ### Importing Libraries

# %%
from bs4 import BeautifulSoup 

import requests 

import csv

import pandas as pd

import re

# %% [markdown]
# ### Scraping Laptop Data from Flipkart website

# %%
# Declaring empty Lists

products=[]

prices=[]

originals=[]

links=[]

# Scraping data from different pages

for i in range(1,4):
    url=(f"https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.discount_range_v1%255B%255D%3D10%2525%2Bor%2Bmore&page={i}")

    response = requests.get(url)

    htmlcontent = response.content

    soup = BeautifulSoup(htmlcontent,"html.parser")
    
    product=soup.find('div',attrs={'class':'_4rR01T'})
    
    for a in soup.findAll('a',href=True, attrs={'class':'_1fQZEK'}):

        name=a.find('div',attrs={'class':'_4rR01T'})

        price=a.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
    
        original=a.find('div',attrs={'class':'_3I9_wc _27UcVY'})

        link = a.find('img',attrs={'src': re.compile("^https://")})

        products.append(name.text)

        prices.append(price.text)

        originals.append(original.text)

        links.append(link.get('src'))

# %%
# Printing Extracted Data

for i in range(len(products)):
    print(i+1)
    print("Product Name:-  ", products[i])
    print("Offer Price:-  ", prices[i])
    print("Original Price:-  ", originals[i])
    print("Product Image:- ", links[i],"\n")
# Out:
# 1
# Product Name:-   Lenovo ThinkPad E15 Core i3 11th Gen - (4 GB/256 GB SSD/DOS) E15 Laptop
# Offer Price:-   ₹39,990
# Original Price:-   ₹46,990
# Product Image:-  https://rukminim1.flixcart.com/image/312/312/kngd0nk0/computer/w/d/v/na-laptop-lenovo-original-imag24kxyrhycyxk.jpeg?q=70
#
# 2
# Product Name:-   Lenovo ThinkPad E15 Core i7 11th Gen - (16 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) E15 Laptop
# Offer Price:-   ₹87,990
# Original Price:-   ₹1,01,606
# Product Image:-  https://rukminim1.flixcart.com/image/312/312/kngd0nk0/computer/k/q/5/na-laptop-lenovo-original-imag24kvhrgqvjut.jpeg?q=70
#
# 3
# Product Name:-   acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650...
# Offer Price:-   ₹53,990
# Original Price:-   ₹84,999
# Product Image:-  https://rukminim1.flixcart.com/image/312/312/kcc9q4w0/computer/h/t/g/acer-na-gaming-laptop-original-imafthr8aa4rsjpn.jpeg?q=70
#
# 4
# ...

# %%
# Create a Data Frame

df = pd.DataFrame({'Product Name':products,'Offer Price':prices,'Original Price':originals,'Product Image':links})

df.head(60)
# Out:
#                                          Product Name Offer Price  \
# 0   Lenovo ThinkPad E15 Core i3 11th Gen - (4 GB/2...     ₹39,990
# 1   Lenovo ThinkPad E15 Core i7 11th Gen - (16 GB/...     ₹87,990
# 2   acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...     ₹53,990
# 3   HP 14s Ryzen 3 Quad Core 4300U - (8 GB/512 GB ...     ₹39,490
# 4   HP 14s Core i3 11th Gen - (8 GB/512 GB SSD/Win...     ₹44,990
# 5   acer Aspire 7 Ryzen 5 Quad Core 3550H - (8 GB/...     ₹49,990
# 6   MSI GF63 Thin Core i5 9th Gen - (8 GB/512 GB S...     ₹54,990
# 7   Lenovo ThinkPad E15 Core i3 11th Gen - (4 GB/2...     ₹44,990
# 8   HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...     ₹40,490
# 9   Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...     ₹42,990
# 10  ASUS Vivobook Gaming Core i5 9th Gen - (8 GB/5...     ₹58,990
# 11  acer Aspire 7 Ryzen 5 Quad Core 3550H - (8 GB/...     ₹50,990
# 12  HP Pavilion Gaming Ryzen 5 Quad Core 3550H - (...     ₹59,990
# ...

# %%
# converting Data Frame to CSV
df.to_csv('Laptop.csv')

# %%
# converting Data Frame to Excel
df[['Product Name',	'Offer Price','Original Price','Product Image']].to_excel('Laptop1.xls')
